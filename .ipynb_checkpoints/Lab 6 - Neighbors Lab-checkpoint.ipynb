# %% [markdown]
# ## Lab 6 - Neighbors Lab

# %% [markdown]
# ### Implementing the $k$-NN Classification
# * Apply the $k$-NN Algorithm
# * Using Cross Validation
# * Apply Scaling

# %%
# %matplotlib inline
from __future__ import division
import pandas as pd
import numpy as np
from seaborn import plt
from sklearn.datasets import load_iris

load_iris?

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets, feature_selection
from sklearn.cross_validation import train_test_split, cross_val_score

# %%
# Various variables we'll need to set intially.
n_neighbors = range(1, 51, 2) # creating range for k values from 1 to 51 in increments of 2

# %%
# Load in the data
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### Paramter Search

# %%
# PARAMETER SEARCH
# Create the training (and test) set using scikit-learn's train_test_split function
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=12)

# Try this sequence again with the following random seed.
# observe how it changes the scores of K quite dramatically
# X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=8)

# %%
# Loop through each neighbors value from 1 to 51 and append
# the scores
scores = []
for n in n_neighbors:
    clf = neighbors.KNeighborsClassifier(n)
    clf.fit(X_train, y_train)
    scores.append(clf.score(X_test, y_test))

# %%
plt.figure(figsize=(18,6))
_ = plt.plot(n_neighbors, scores, linewidth=3.0)
# looks like 11 is optimal number for k using this particular training/test split...at k=11 generalization score = 100%

# %% [markdown]
# ### Application of Cross Validation

# %%
# Cross Validation
from sklearn.cross_validation import cross_val_score
clf = neighbors.KNeighborsClassifier(11, weights='uniform')
scores = cross_val_score(clf, iris_df.values, iris.target, cv=5) #makes 5 splits and train on each split
print scores
# Out:
# [ 0.93333333  1.          1.          0.96666667  1.        ]

# %%
np.mean(scores)
# Out:
# 0.98000000000000009

# %%
# Below returns highest signifiance for features 2 and 3
# (remember, Python uses index 0). 
n = np.arange(len(iris.feature_names))

fig = plt.figure(figsize=(18,6))
ax = fig.add_subplot(111)

ax.bar(n, feature_selection.f_classif(iris.data, iris.target)[0]) #tells you how much the features contribute to identifying the target

xtickNames = ax.set_xticklabels(iris.feature_names)
ax.set_xticks(n)
_ = plt.setp(xtickNames, rotation=45, fontsize=16)

# %%
# fit only last two features
clf = neighbors.KNeighborsClassifier(11, weights='uniform')
clf.fit(iris.data[:, 2:4], iris.target)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=11, p=2, weights='uniform')

# %%
h = .02  # step size in the mesh
# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
x_min, y_min = iris_df.min()[['petal length (cm)', 'petal width (cm)']]
x_max, y_max = iris_df.max()[['petal length (cm)', 'petal width (cm)']]

# %%
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)

# %%
plt.figure(figsize=(18,6))
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
# Plot also the training points
plt.figure(figsize=(18,6))
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
plt.scatter(iris_df['petal length (cm)'], iris_df['petal width (cm)'], c=iris.target, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("3-Class classification (k = {}, weights = '{}')".format(clf.n_neighbors, clf.weights))

# %% [markdown]
# ### Scaling

# %%
# Scaling
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
from sklearn.preprocessing import scale
# noticed std is very different so we want to scale
df_norm = pd.DataFrame(scale(iris.data), columns=iris.feature_names)

# %%
df_norm.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0          -0.900681          1.032057          -1.341272         -1.312977
# 1          -1.143017         -0.124958          -1.341272         -1.312977
# 2          -1.385353          0.337848          -1.398138         -1.312977
# 3          -1.506521          0.106445          -1.284407         -1.312977
# 4          -1.021849          1.263460          -1.341272         -1.312977

# %%
df_norm.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count       1.500000e+02      1.500000e+02       1.500000e+02
# mean       -1.468455e-15     -1.657933e-15      -1.515825e-15
# std         1.003350e+00      1.003350e+00       1.003350e+00
# min        -1.870024e+00     -2.438987e+00      -1.568735e+00
# 25%        -9.006812e-01     -5.877635e-01      -1.227541e+00
# 50%        -5.250608e-02     -1.249576e-01       3.362659e-01
# 75%         6.745011e-01      5.692513e-01       7.627586e-01
# max         2.492019e+00      3.114684e+00       1.786341e+00
#
#        petal width (cm)
# count      1.500000e+02
# mean      -8.052818e-16
# std        1.003350e+00
# min       -1.444450e+00
# 25%       -1.181504e+00
# 50%        1.332259e-01
# 75%        7.905908e-01
# max        1.710902e+00

# %% [markdown]
# #### Rerun the parameter search with random_state=8. Do you get the same result for the optimal k

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=8)

# %%
my_scores = []
for n in n_neighbors:
    clf = neighbors.KNeighborsClassifier(n)
    clf.fit(X_train, y_train)
    my_scores.append(clf.score(X_test, y_test))

# %%
plt.figure(figsize=(18,6))
_ = plt.plot(n_neighbors, my_scores, linewidth=3.0)

# %%
# optimal k = 9

# %% [markdown]
# #### Rerun the lab using scaled data

# %%
X_train, X_test, y_train, y_test = train_test_split(scale(iris.data), iris.target, test_size=0.3, random_state=8)

# %%
scaled_data_scores = []
for n in n_neighbors:
    clf = neighbors.KNeighborsClassifier(n)
    clf.fit(X_train, y_train)
    scaled_data_scores.append(clf.score(X_test, y_test))

# %%
plt.figure(figsize=(18,6))
_ = plt.plot(n_neighbors, scaled_data_scores, linewidth=3.0)

# %%
# Optimal k=9
clf = neighbors.KNeighborsClassifier(9, weights='uniform')
scaled_data_scores = cross_val_score(clf, df_norm.values, iris.target, cv=5)
print scaled_data_scores
# Out:
# [ 0.96666667  0.96666667  0.96666667  0.9         1.        ]

# %%
np.mean(scaled_data_scores)
# Out:
# 0.95999999999999996

# %%
fig = plt.figure(figsize=(18,6))
ax = fig.add_subplot(111)
n = np.arange(len(iris.feature_names))
ax.bar(n, feature_selection.f_classif(scale(iris.data), iris.target)[0])

xtickNames = ax.set_xticklabels(iris.feature_names)
ax.set_xticks(n)
_ = plt.setp(xtickNames, rotation=45, fontsize=16)

# %%
clf = neighbors.KNeighborsClassifier(9, weights='uniform')
clf.fit(scale(iris.data)[:, 2:4], iris.target)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=9, p=2, weights='uniform')

# %%
x_min, y_min = df_norm.min()[['petal length (cm)', 'petal width (cm)']]
x_max, y_max = df_norm.max()[['petal length (cm)', 'petal width (cm)']]

# %%
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
# Put the result into a color plot
Z = Z.reshape(xx.shape)

# %%
plt.figure(figsize=(18,6))
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
plt.figure(figsize=(18,6))
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
plt.scatter(df_norm['petal length (cm)'], df_norm['petal width (cm)'], c=iris.target, cmap=cmap_bold)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("3-Class classification (k = {}, weights = '{}')".format(clf.n_neighbors, clf.weights))
